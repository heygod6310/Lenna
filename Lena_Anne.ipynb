# %%
# !pip install opencv-python

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
LL=cv2.imread("300px-Lenna.jpg")
LL_plt=cv2.cvtColor(LL, cv2.COLOR_BGR2RGB)
AA=cv2.imread("anne.jpg")
AA_plt=cv2.cvtColor(AA, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(LL_plt)
plt.subplot(1,2,2)
plt.imshow(AA_plt)
